# %% [markdown]
# # Percentiles

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# -0.0021843762177964935

# %%
np.percentile(vals, 90)
# Out:
# 0.6303687627073694

# %%
np.percentile(vals, 20)
# Out:
# -0.4226285257017852

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters when creating the test data. What effect does it have on the percentiles?

# %%
#What if we were to try with a different standard deviation value?
vals = np.random.normal(0, 1.2, 10000)
plt.hist(vals, 50)
plt.show()

# %%
#We can see that a larger standard deviation widened the plot
#What if we were to change the sample size to something much smaller in order to introduce more random variation?
vals = np.random.normal(0, 0.5, 500)
plt.hist(vals, 50)
plt.show()

# %%
#We can see that with a smaller sample size, the plot is not as smooth as there is more localized variation in the plot
